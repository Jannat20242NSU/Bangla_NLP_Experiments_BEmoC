# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install bnlp_toolkit
# Out:
# Requirement already satisfied: bnlp_toolkit in /opt/conda/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (0.1.99)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (4.3.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (1.11.4)
# Requirement already satisfied: sklearn-crfsuite in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (0.3.6)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (4.66.1)
# Requirement already satisfied: ftfy in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (6.1.3)
# Requirement already satisfied: emoji==1.7.0 in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (1.7.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (2.31.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /opt/conda/lib/python3.10/site-packages (from ftfy->bnlp_toolkit) (0.2.12)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->bnlp_toolkit) (6.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->bnlp_toolkit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (2023.11.17)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp_toolkit) (0.9.9)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp_toolkit) (0.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
train_df = pd.read_excel("/kaggle/input/bemoc-dataset/cleaned_BEmoC7k.xlsx")

# %%
train_df
# Out:
#                                                    TEXT  classes
# 0                              নাইমা কি করবেন আমরা জানি  sadness
# 1                          ভাই সব আপনাদের খুব ভাল লাগছে      joy
# 2     গাঞ্জা খাইয়া নিউজ শেয়ার করছে দিগন্ত  বয়কটে ...    anger
# 3     অনেক ধন্যবাদ স্যার যশোরে ইত্যাদি অনুষ্ঠান করার...      joy
# 4         বর্তমানে মুসলমান মারে যে জন সে জন হয়েছে ঈশ্বর  disgust
# ...                                                 ...      ...
# 6995  হে আল্লাহ আপনি আমাদের দেশের প্রতি সহায়ক হন   ...  sadness
# 6996  ঈদ ছারাও যুদি বাংলাদেশ ঈদের খুশির অামেজ পান তব...      joy
# 6997  বছরের সবচেয়ে সেরা ভিডিও দেখেছি  আমাদের দেশের স...      joy
# 6998   কিরে মিথ্যা কথা কস কেন গতদিন আমি আর আসিফ আসছি...    anger
# 6999  \nভাইরেভাই বেস্ট এইটা বেস্ট\nএইরকম পারফেক্ট গল...      joy
#
# [7000 rows x 2 columns]

# %%
train_df.dropna(inplace=True)

# %%
longest_string = max(train_df["TEXT"], key=len)
print(len(longest_string))
# Out:
# 1093

# %%
from bnlp import CleanText

clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=False,
   remove_email=False,
   remove_emoji=False,
   remove_number=False,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="<URL>",
   replace_with_email="<EMAIL>",
   replace_with_number="<NUMBER>",
   replace_with_digit="<DIGIT>",
   replace_with_punct = "<PUNC>"
)

train_df['TEXT'] = train_df['TEXT'].apply(clean_text)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
longest_string = max(train_df["TEXT"], key=len)
print(len(longest_string))
# Out:
# 1120

# %%
train_df["classes"].value_counts()
# Out:
# classes
# joy         1524
# disgust     1356
# sadness     1327
# anger       1052
# fear         962
# surprise     779
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(train_df, test_size=0.2,stratify=train_df['classes'],random_state=42)

# %%
X_train  =  train_df['TEXT'].values.tolist()
y_train = train_df['classes'].tolist()

# %%
X_test =  test_df['TEXT'].values.tolist()
y_test = test_df['classes'].tolist()

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /opt/conda/lib/python3.10/site-packages (0.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn) (3.2.0)

# %%
from collections import Counter

# Counter(y_train)

# %%
print(Counter(X_train))
print(Counter(y_train))
# Out:
# Counter({'বেসামরিক বিমান পরিবহন ও পর্যটন প্রতিমন্ত্রী মাহবুব আলী বলেছেন    অর্থ বছরে বিমান বাংলাদেশ এয়ারলাইন্সের লাভ হয়েছে  কোটি টাকা  বুধবার   জুলাই  সচিবালয়ে বিমান পরিবহনের সম্মেলন কক্ষে এ তথ্য জানান তিনি ': 4, 'কিছুক্ষণ আগে লক্ষ্য করলাম  কিছু মানুষ বাঙলাদেশের পাসপোর্টে লেখা             লেখাটি শেয়ার করছে  অবাক হলাম  এই সব মানুষই দিন আগে মানবতা নিয়ে উচ্চবাচ্য করছিলো ': 3, 'ওদের কিছু করতে পারবে না কারন তাদের কথায় থানা পুলিশ উঠে আর বসে  আর এমপি মন্ত্রি তো এদের হাতের ময়লা  আর এদের খমতায় সাধারন জনগণের জায়গা জমি আর টাক্কা পয়সা হাতিয়ে নিয়ে আজ কয়েশো কুটি টাকার মালিক  অনেক লোককে পথের ফকির করে দিয়েছে  দেখি কি বিচার করে নাকি টাকা পয়সা নিয়ে ছেড়ে দেয় ': 3, 'স্বাস্থ্য অধিদপ্তরের মহাপরিচালক আবুল কালাম আজাদ প্রথম আলোকে বলেন  ডেঙ্গু মোকাবিলায় সরকারি হাসপাতালগুলোকে বিশেষ বরাদ্দ দেওয়া হয়েছে  সদর হাসপাতালে  লাখ এবং উপজেলা হাসপাতালকে  লাখ টাকা দেওয়া হয়েছে  হাসপাতালগুলো বরাদ্দের টাকা দিয়ে কিট সংগ্রহ করতে পারবে ': 2, 'তারা ঠিকই ব্যাডমিন্টন খেলে  অথচ মানুষের প্রজেক্ট আইডিয়া দেখার টাইম নাই  আমাদের  এর টাইমে তাদের টাইম হয় ': 2, 'ভদ্র মানুষ দেখেছেন তাহসানকে দেখেন তাহলে বুঝবেন মানুষ এতো ভালো হয় কিভাবে   ': 2, 'ভাই আমরা আপনাকে  করি  আপনি সব সময় সত্যের সাথে থাকেন  আল্লাহ আপনাকে হেফাজত করুক': 2, 'অনেক অনেক ধন্যবাদ      কে  আমি আমার অডার টা হাতে পেয়ে  ব্যাবহার করে ও খুব আরাম টাইম মত পোডাক্ট হাতে পেয়েছি সব মিলিয়ে খুব খুশি আমি ': 2, 'মাশা আল্লাহ খাওয়ার শুরুতে বিসমিল্লাহ বলায়   করলাম আজ থেকে নিয়মিত ভিডিও দেখবো ইনশা আল্লাহ': 2, 'প্রতিটা মানুষের জন্যই কখনো না কখনো জয় আসে  আজ তুমি যাকে হারাবে  কখনো না কখনো তার কাছেই তোমার হারতে হবে  প্রত্যক্ষভাবে না হলেও পরোক্ষভাবে প্রকৃতি কাউকে কখনো ঠকায় না': 2, 'লেবুর শরবতে আয়েশ করে চুমুক দিতে দিতে পাশের দেয়ালে দৃষ্টি ফেরাতেই যদি চোখ আটকে যায় হাতে আঁকা ছবির দিকে  যে ছবিতে শোভা পাচ্ছে বৃষ্টিভেজা একফালি লেবুর ছবি  কী  গেল তো স্বাদ দ্বিগুণ হয়ে  আহা  স্নিগ্ধতা আর সতেজভাব যেন মুহূর্তেই ছেয়ে ফেলেছে শরীর ও মন  এ তো গেল ছবির কথা  অন্দরসজ্জায় লেবুর রকমারি সাজে আপনার প্রিয় অঙ্গন দেবে সতেজ হাসি': 2, 'আমি অপূর্ব ভাইয়ার অনেক বড় একজন ফ্যেন   আমার কাছে অপূর্ব ভাইয়ার সকল নাটক ভালো লাগে           ': 2, 'একদিন এই বেইলি রোডে কতো ভিজেছি রিক্সায়  আজ তুমি নেই      ': 2, 'আমি চাইনি তুমি কখনো কষ্ট পাও  আমি চেয়েছি তুমি সুখী হও  তাইতো কোনো অভিযোগ করিনি অকারণে চলে গেছো বলে': 2, 'লোকাল চ্যানেলগুলোতে বারবার দেখাচ্ছে যে শহরের জেলখানা থেকে এক ভয়ঙ্কর খুনী পালিয়েছে  টিভিতে খুনির ছবিও দেখাচ্ছে  ফোন করে কেউ পুলিশে খবর দিয়েছে যে তাকে দেখা গেছে এই আবাসিক এলাকায়  গা শিউরে ওঠার মতো খবর ': 2, 'খুব দুঃখ লাগতেসে বলতে  তাও বলতেই হচ্ছে যে জুনিয়র ব্যাচগুলোর কাছে মোস্ট সিনিয়র হিসেবে আমার নিজের এট লিস্ট পার্সোনালি মনে হয়না আমাদের মতো কেউ এতো বেশি  হইসে আজ পর্যন্ত  এরপরও যদি আমরা নিজের ব্যাপারে চিন্তা না করে সামষ্টিক চিন্তা করি তাহলে সেটা আসলে উলুবনে মুক্তা ছড়ানোর মতো হয়ে যায়  আর দিনশেষে ভোগটা আমাদেরকেই করতে হবে ': 2, 'প্রতিটি ক্যাম্পাসে এই ধরনের পদক্ষেপ নিলে ক্যাম্পাসের বর্তমান শিক্ষার্থীরা কিছুটা হলেও উপকৃত হবে \nধন্যবাদ        ': 2, 'আজ সকালে সাধন আচার্য্যকে ফোন করলেন  অনেক দিন পর  নিগার ডিসপ্লেতে পরিচিত নামটা দেখেই ভীষণ অবাক হয়েছে  ': 2, '  যারা নোংরা তাদের মুখ দিয়ে নোংরা কোথায় আসবে ভালো কথা আশা করা যায় না': 2, '       এইটা শুধু আমার প্রাণের দেশে সম্ভব এরকম ভাষা  এরকম দৃশ্য': 2, ' হোটেলের সামনে পৌছে গাড়ি থেকে নামতেই স্নো ফল শুরু হয়ে গেছে৷   °  স্নো ফল পেয়েই মনে হলো জোবনে আর কোন সাধ নেই  সব সাধ পূরণ হয়ে গেছে  আর আমাদের রুম থেকে জানালা দিয়ে যে পাহাড়ের দৃশ্যটা দেখা যাচ্ছিলো সেই সাথে পূর্ণ চাদ ষোলকলা পূর্ণ হয়ে গেলো ': 2, 'আপনার জন্য আমার হেসে হেসে বুকে ব্যাথা হয়ে গেল  তাই কষ্ট করে  নিতে হলো  এখনো কাশি হচ্ছে ': 2, 'আমি আবারো শিউরে উঠলাম এটা অসম্ভব হতেই পারে না এটা একজন মৃত মানুষের আমার সাথে কথা বলার কোন কারনই নেই  তাও আবার ফোনের মত একটি আধুনিক যন্ত্রের সাহায্যে ': 2, 'গানের রাজা  প্রতিযোগিতার প্রথম আসরে চ্যাম্পিয়ন হতে পারেনি শফিকুল ইসলাম  সে হয়েছিল প্রথম রানারআপ  ওই সময় সামাজিক যোগাযোগমাধ্যমে তা নিয়ে অনেকেই নানা মন্তব্য করেন  চ্যাম্পিয়ন না হতে না পারলেও সেই শফিকুল ইসলামের প্রথম মৌলিক গান  ভাবতে ঘেন্না লাগে  সাড়া ফেলেছে  ইউটিউবে গানটির ভিডিও প্রকাশের  ঘণ্টার মাথায়  লাখ  হাজারবার দেখা হয়েছে': 2, 'কির ...
# Counter({'joy': 1219, 'disgust': 1085, 'sadness': 1062, 'anger': 841, 'fear': 770, 'surprise': 623})

# %%
np.array(X_train).shape
# Out:
# (5600,)

# %%
X_train = np.array(X_train).reshape(-1, 1)

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=0)
X_train, y_train = ros.fit_resample(X_train, y_train)

# %%
X_train = np.array(X_train).reshape(7314,)

# %%
print(Counter(X_train))
print(Counter(y_train))
# Out:
# Counter({'চুরি করছে তো করছে  ক্রেডিট দিছে আরেকজনকে  এইডাই সবচেয়ে বড়  মনে হইল আমার কাছে ': 8, 'আজ সকালে সাধন আচার্য্যকে ফোন করলেন  অনেক দিন পর  নিগার ডিসপ্লেতে পরিচিত নামটা দেখেই ভীষণ অবাক হয়েছে  ': 6, 'রাতে নোটিফিকেশন আসছে  ক্লিক করলাম বাট লেখা আসছে   হলো এটা ': 6, 'কতক্ষণ ঘুমিয়ে ছিলেন কে জানে  হঠাৎ একটা অদ্ভুত আওয়াজ আর অস্বস্তির মধ্যে তার ঘুমটা গেল ভেঙে  গভীর ঘুমে আচ্ছন্ন মানুষের হঠাৎ ঘুম ভেঙে গেলে সামান্য সময় লাগে প্রকৃতিস্থ হতে ': 6, 'চট্টগ্রাম বিশ্ববিদ্যালয়ে স্নাতক প্রথম বর্ষের বিভিন্ন বিভাগে ভর্তি হতে আবেদন করেছেন  লাখ  হাজার  জন শিক্ষার্থী  এর আগে এত–সংখ্যক আবেদন আর জমা পড়েনি  আজ বুধবার প্রথম আলোকে বিশ্ববিদ্যালয়ের আইসিটি সেলের পরিচালক মো  হানিফ সিদ্দিকী বলেন  গতবারের মতো এবারও আসন রয়েছে  হাজার টি  ফলে প্রতি আসনের জন্য লড়বেন  জন': 6, 'এতো তাড়াতাড়ি ভিডিও দেখতে পাবো ভাবতেই পারিনি      আশা করি তোমাদের    এর অনেক উন্নতি হবে   ': 6, 'দিনক্ষণের কোন হিসেব নেই মোজাম্মেল ভাইয়ের  সম্পর্কের পরেও পরপর তিন বছর ঊষা আপুর জন্মদিনের দিনটা ভুলে বসে ছিলেন  তেমন মানুষটা যখন আবার   সালের  ফেব্রুয়ারি  তারিখটাকে ডায়েরিতে টুকে রাখেন  সেটা সত্যিই অবাক করা বিষয় ': 6, 'ছেলেটা কেমন অদ্ভুতভাবে সব কথার জবাব দিচ্ছে  যেন সে আগে থেকেই জানে আমি ওকে কী জিজ্ঞেস করবো ': 6, 'লোকাল চ্যানেলগুলোতে বারবার দেখাচ্ছে যে শহরের জেলখানা থেকে এক ভয়ঙ্কর খুনী পালিয়েছে  টিভিতে খুনির ছবিও দেখাচ্ছে  ফোন করে কেউ পুলিশে খবর দিয়েছে যে তাকে দেখা গেছে এই আবাসিক এলাকায়  গা শিউরে ওঠার মতো খবর ': 5, 'ওদের কিছু করতে পারবে না কারন তাদের কথায় থানা পুলিশ উঠে আর বসে  আর এমপি মন্ত্রি তো এদের হাতের ময়লা  আর এদের খমতায় সাধারন জনগণের জায়গা জমি আর টাক্কা পয়সা হাতিয়ে নিয়ে আজ কয়েশো কুটি টাকার মালিক  অনেক লোককে পথের ফকির করে দিয়েছে  দেখি কি বিচার করে নাকি টাকা পয়সা নিয়ে ছেড়ে দেয় ': 5, 'নানা সূত্রে জানা গেল  বিপিএলে ভালো খেলা কয়েকজন খেলোয়াড়ের ঠাঁই মিলছে দলে  এবার বিপিএলের পারফরম্যান্স দিয়ে জায়গা পাওয়া খেলোয়াড়দের মধ্যে সবচেয়ে বড় চমক হতে পারেন হাসান মাহমুদ ': 5, 'নানা রকম চেনা অচেনা পাখির কলতান  অরণ্যর নিস্তব্ধতার মাঝে নানা শব্দ  আদিবাসিদের মাছ ধরা  বাচ্চাদের গোছল করা আরো কত কি  আশ্চর্য এ যেন চির চেনা জগত ফেলে অচেনার এক জগত ': 5, 'সুদী উন্নুচা আর সুচী এই টাই শয়তান কোন কামের না': 5, 'হাতের ডান পাশে সিঁড়ির শেষ মাথার ছাদের দেয়াল ঘেষে কে যেনো বসে আছে   ভয়ে আমার বুক তখন হাপারের মতো উঠা নামা করছে  ': 5, 'গত বুধবার এক বিবৃতি দিয়ে রাজকীয় দায়িত্ব ছাড়ার ঘোষণা দেন প্রিন্স হ্যারি ও তাঁর স্ত্রী মেগান   সিনিয়র রয়্যাল  উপাধি না নিয়ে তাঁরা স্বাবলম্বী হয়ে বেঁচে থাকতে চান': 5, ' লাখ বছর আগে বিশালাকার বরফের পাহাড়ে ঢাকা ছিল পৃথিবী  বরফে ঢাকা শীতল এ সময়টিকে বরফ যুগ হিসেবে চিহ্নিত করা হয় বিজ্ঞানীরা জানান  অ্যান্টার্কটিকার বরফ ধীরে ধীরে বাড়ছে  অ্যান্টার্কটিকায় জমতে থাকা এ বরফ সমুদ্রের ওপর ঢাকনার মতো কাজ করছে  এতে সমুদ্র থেকে বায়ুমণ্ডলে কার্বন ডাই অক্সাইড নিঃসরিত হতে পারছে না  এ বরফই নতুন করে পৃথিবীতে বরফ যুগের সূচনা করতে পারে ': 5, 'আমার হঠাৎ মনে পড়লো কাল রাতের কথা  সাথেসাথেই ঘামতে লাগলাম আমি  আম্মু এক গ্লাস পানি এনে দিলেন  এক শ্বাসে সব পানিই খেয়ে নিলাম ': 5, 'পরমুহূর্তেই ছাদের টিনে শুরু হলো লাফালাফি বিকট শব্দে  কৌতূহলী অঘোরনাথবাবু ছাদে গিয়ে দেখেন কেউ নেই ছাদ একেবারে খালি ': 5, 'হ্যাঁ  কাঁচা মরিচ আকস্মিকই হিট নায়িকাদের মতো আলোচিত হয়ে উঠেছে  কারণ এর দাম  দশ বিশ টাকা কেজির মরিচ এখন সেঞ্চুরি  ডাবল সেঞ্চুরি পার করে  গিয়ে নট আউট রয়েছে  এভাবে টিকে থাকলে ট্রিপল সেঞ্চুরির রেকর্ড গড়লেও অবাক হওয়ার কিছু থাকবে না ': 5, 'চুয়াডাঙ্গায় হাটবাজারগুলোতে ধান চালের দাম লাফিয়ে লাফিয়ে বাড়ছে  তিন সপ্তাহের ব্যবধানে পাইকারি বাজারে প্রকারভেদে প্রতি মণ   কেজি  চালের দাম  থেকে  টাকা পর্যন্ত বেড়েছে ': 5, 'এদিকে রাতের বেলা আলেকজান্ডার খবর পেলেন পার্সিয়ানদের রাজাদের রাজার তাঁবু পাওয়া গিয়েছে  শুধু সোনা  রূপা কিংবা বিলাসদ্রব্যই নয়  দারিউস পিছনে ফেলে রেখে গিয়েছে তার স্ত্রী স্তাতেইরা  মা সিসিগ্যাম্বিস আর নিজের ছেলেকেও ': 5, ' দিনের বেলা একা থাকা ভয় না করলেও রাতের বেলা  ভয় করত  আর প্রথম চার দিন প্রাকৃতিক ডাকেও সাড়া দেয় নি ভূতের ভয়ে ': 5, 'রাতে বাথরুমে যেতে হলে রুমে যে আছে তাকে জাগিয়ে তুলে বাথরুমের সামনে দাঁড় করিয়ে সে বাথরুমে যায় এবং তার সাথে কথা বলতে থাকে  ঘুমের সময় রাতের বেলায় কোনো শব্দ হলেই সে চিৎকার করে ওঠে  তার মনে হয় কোনো অশরীরী কিছু বা ভূত এমন শব্দ করছে এবং এ ...
# Counter({'disgust': 1219, 'joy': 1219, 'sadness': 1219, 'anger': 1219, 'surprise': 1219, 'fear': 1219})

# %%
pip install ktrain
# Out:
# Collecting ktrain
#   Downloading ktrain-0.39.0.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 46.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.7.4)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.0.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ktrain) (21.3)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 44.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.42.1)
# Requirement already satisfied: charset-normalizer in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.2.0)
# Collecting chardet (from ktrain)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.17.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (4.36.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras_bert>=0.86.0->ktrain) (1.24.3)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: regex>2016 in /opt/conda/lib/python3.10/site-packages (from syntok>1.3.3->ktrain) (2023.8.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.19.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (2023.11.17)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tika->ktrain) (68.1.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.17.0->ktrain) (2023.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers>=4.17.0->ktrain) (4.5.0)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 14.1 MB/s eta 0:00:00
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.39.0-py3-none-any.whl size=25319738 sha256=ed8670b2a693600b087436e18e488cff3dda3d8247d2f182612309ccafe2c77f
#   Stored in directory: /root/.cache/pip/wheels/98/fd/0a/ef6252223f3d2c49b06d18e71c74caa43bbf4c64a8c183a46e
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33499 sha256=0d39a57db095bf5dcb214dab77b1edebcf16c175087dc89e88c4a6651587a82e
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12285 sha256=f2375d055bf43f8b2f558442087a5b5eff2c710866f4437b0d6f5ca3e17993d0
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3945 sha256=478d807d8d5e6d82c7b5658b31d0ad06bea993f5c6ce6f210d729156b3aadbae
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4654 sha256=949b2ef2f945dacd1d53277c6980a7ba504554b26e9d800658d1f7c81f5f9d70
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14977 sha256=3d7d40a577236f7748b4581fcd997cd11505b4d23f71197af12071bb474fe386
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6945 sha256=a75f0806b2164e5ec4b32ba92b4f3f0a6025d20aa8abe731e3b66dd534887147
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4969 sha256=207eed8f089c998815b73138f4ba743528660b6280b7eee2eadad117d49e7e89
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=56aa071aeb1ceb12d2384648ea35585442a0ad6a178f8d506ee991e15ca5f42e
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=b4c91f09ea998f3272421dfd65ae9d19f78c4bc8f9a2a92756d17e2c8161493a
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=9663cefb690ac7f1e9937392b0f7297f40b3318f985c1112b6fe3aa47224cd68
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention langdetect tika
# Installing collected packages: whoosh, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, chardet, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed chardet-5.2.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.39.0 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import ktrain
from ktrain import text
MODEL_NAME = 'csebuetnlp/banglabert'
t = text.Transformer(MODEL_NAME, maxlen=500)
# Out:
# config.json:   0%|          | 0.00/586 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
trn = t.preprocess_train(X_train, y_train)
val = t.preprocess_test(X_test, y_test)
# Out:
# preprocessing train...
# language: bn
# train sequence lengths:
# 	mean : 21
# 	95percentile : 41
# 	99percentile : 59
# tokenizer_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/528k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: bn
# test sequence lengths:
# 	mean : 21
# 	95percentile : 41
# 	99percentile : 61
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print(trn)
# Out:
# <ktrain.text.dataset.TransformerDataset object at 0x7e5c9d27c4f0>

# %%
import matplotlib.pyplot as plt

# Calculate token lengths for train and test datasets
train_token_lengths = [len(t.split()) for t in X_train]
test_token_lengths = [len(t.split()) for t in X_test]

# Plot token length distribution
plt.figure(figsize=(10, 6))
plt.hist(train_token_lengths, bins=50, alpha=0.5, color='blue', label='Train')
plt.hist(test_token_lengths, bins=50, alpha=0.5, color='orange', label='Test')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.title('Token Length Distribution')
plt.legend()
plt.show()

# %%
model = t.get_classifier()

# %%
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=8)

# %%
# Adding early stopping callback from TensorFlow
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='auto')

# %%
history = learner.autofit(2e-5, 10, callbacks=[early_stopping])
# Out:
# begin training using triangular learning rate policy with max lr of 2e-05...
# Epoch 1/10
# 915/915 [==============================] - 555s 576ms/step - loss: 1.2185 - accuracy: 0.5324 - val_loss: 0.8224 - val_accuracy: 0.6871
# Epoch 2/10
# 915/915 [==============================] - 521s 569ms/step - loss: 0.6709 - accuracy: 0.7509 - val_loss: 0.7787 - val_accuracy: 0.7171
# Epoch 3/10
# 915/915 [==============================] - 521s 569ms/step - loss: 0.4621 - accuracy: 0.8407 - val_loss: 0.8234 - val_accuracy: 0.7243
# Epoch 4/10
# 915/915 [==============================] - 520s 569ms/step - loss: 0.3035 - accuracy: 0.9089 - val_loss: 0.8884 - val_accuracy: 0.7279
# Epoch 5/10
# 915/915 [==============================] - 521s 570ms/step - loss: 0.2187 - accuracy: 0.9367 - val_loss: 1.0005 - val_accuracy: 0.7186
# Epoch 6/10
# 915/915 [==============================] - 521s 570ms/step - loss: 0.1568 - accuracy: 0.9575 - val_loss: 1.0791 - val_accuracy: 0.7214
# Epoch 7/10
# 915/915 [==============================] - 521s 569ms/step - loss: 0.1207 - accuracy: 0.9670 - val_loss: 1.1750 - val_accuracy: 0.7264

# %%
# Save the trained model
learner.save_model('/kaggle/output/bemoc.zip')

# %%
classes=t.get_classes()

# %%
cm = learner.validate(class_names=t.get_classes())
# Out:
# 44/44 [==============================] - 12s 188ms/step
#               precision    recall  f1-score   support
#
#        anger       0.66      0.57      0.61       211
#      disgust       0.57      0.63      0.60       271
#         fear       0.86      0.79      0.82       192
#          joy       0.84      0.86      0.85       305
#      sadness       0.71      0.76      0.73       265
#     surprise       0.76      0.69      0.72       156
#
#     accuracy                           0.73      1400
#    macro avg       0.73      0.72      0.72      1400
# weighted avg       0.73      0.73      0.73      1400

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
# !zip -r mental.zip /kaggle/output/mental-health-rand
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 	zip warning: name not matched: /kaggle/output/mental-health-rand
#
# zip error: Nothing to do! (try: zip -r mental.zip . -i /kaggle/output/mental-health-rand)

# %%
# !ls
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from IPython.display import FileLink
FileLink(r'/kaggle/working/mental-health-rand.zip')
# Out:
# /kaggle/working/mental-health-rand.zip

# %%
# Get predictions for the test data
preds = learner.predict(val)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(preds, axis=1)

# Get the list of class labels
class_labels = t.get_classes()

# Map predicted labels to class labels
predicted_labels = [class_labels[label] for label in predicted_labels]

# Create a DataFrame to store the results
results_df = pd.DataFrame({'Text': X_test, 'True_Label': y_test, 'Predicted_Label': predicted_labels})

# Display the results DataFrame
print(results_df)

# Save the results to a CSV file
results_df.to_csv('classification_results.csv', index=False)
# Out:
# 44/44 [==============================] - 8s 176ms/step
#                                                    Text True_Label  \
# 0     বাইরে কেমন যেন একটা খসখস শব্দ হচ্ছে  তার মনে হ...       fear
# 1     সোনা ও বিদেশি মুদ্রা উদ্ধারের মামলায় পুরান ঢা...    disgust
# 2      সরকারি নিষেধাজ্ঞায় গত  মে থেকে টানা  দিনের জ...    sadness
# 3     আমি তাকে সঙ্গে সঙ্গে চিনে ফেললাম কি আশ্চর্য কি...   surprise
# 4     এবারের মিস ওয়ার্ল্ড বাংলাদেশ এই ভিডিওতে যা দে...    disgust
# ...                                                 ...        ...
# 1395  যেখানে ভিডিওটা বন্ধ হইসে  সিভিলের ওইদিক থেকে ত...       fear
# 1396  গাজীপুরের শ্রীপুর উপজেলার নয়নপুর এলাকায় আজ ম...    sadness
# 1397  নারীরা কোনো উদ্যোগ নিয়ে মাঠে নামতে চাইলে তাঁর...        joy
# 1398  হঠাৎ লোকটা আমাকে কয়েকটি সাংকেতিক শব্দ বললো  আ...       fear
# 1399   আবেশ আতঙ্ক এক ধরণের ভয় যা সময়ের সাথে বেড়ে চলে       fear
#
#      Predicted_Label
# 0               fear
# 1            disgust
# 2            sadness
# 3           surprise
# 4            disgust
# ...              ...
# 1395            fear
# 1396         sadness
# 1397             joy
# 1398            fear
# 1399            fear
#
# [1400 rows x 3 columns]

# %%
results_df["Predicted_Label"].value_counts()
# Out:
# Predicted_Label
# joy         311
# disgust     302
# sadness     285
# anger       183
# fear        177
# surprise    142
# Name: count, dtype: int64

# %%
results_df["True_Label"].value_counts()
# Out:
# True_Label
# joy         305
# disgust     271
# sadness     265
# anger       211
# fear        192
# surprise    156
# Name: count, dtype: int64

# %%
# Calculate token lengths for each description
results_df['Token_Length'] = results_df['Text'].apply(lambda x: len(x.split()))

# Separate data for correct and wrong predictions
correct_preds = results_df[results_df['True_Label'] == results_df['Predicted_Label']]
wrong_preds = results_df[results_df['True_Label'] != results_df['Predicted_Label']]

# Create histograms for token lengths
plt.figure(figsize=(12, 6))
plt.hist(correct_preds['Token_Length'], bins=20, alpha=0.5, label='Correct Predictions')
plt.hist(wrong_preds['Token_Length'], bins=20, alpha=0.5, label='Wrong Predictions')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.title('Token Length Distribution')
plt.legend()
plt.show()

# %%
results_df.tail(25)
# Out:
#                                                    Text True_Label  \
# 1375  করোনা ভাইরাসের জন্য স্কুল বন্ধ করে দেওয়া হয়ে...    disgust
# 1376  আমার কাছে মনে হচ্ছে পুরো পৃথিবী যেন থমকে আছে  ...       fear
# 1377  তার গা শিহরে উঠে ভয়ে  দু  কানের সামনে পিছনের ...       fear
# 1378  এই মানুষটা পারে কাঁটাতারের দুপাশে থাকা মানুষগু...        joy
# 1379  সত্যিই পরিচালকটা অনেক ব্রিলিয়েন্ট       আর জি...        joy
# 1380  পুরাই এপিক হাসতে হাসতে মরে গেলাম     \nআমার তো...        joy
# 1381  কক্সবাজারের কুতুবদিয়া উপজেলায় দুই স্কুলছাত্র...      anger
# 1382                           এগুলো সব ধোন আর নুনু জাত    disgust
# 1383  পুকুর পাড়ে কে যেন মড়ার মত শুয়ে আছে  কাছে গি...       fear
# 1384  সব ঠিক আছে  তুই মেয়ে ভাল  স্ট্রং ক্যারেক্টার ...        joy
# 1385  খুব ছোটবেলায় মাতৃহীন হলেও বিত্তশালী পিতার কড়...    sadness
# 1386  তাহসানের মত মানুষকে মিথিলা ছেড়ে চলে গেছে  কোপ...    disgust
# 1387  প্রায় অনেকটা হাঁটার পর একটা রিকশার দেখা মিললো...   surprise
# 1388  মানুষজন নাকি একই বছরে বারবার আলহামদুলিল্লাহ ওয...    disgust
# 1389  বাফুফেরর সাথে সংশ্লিষ্ট সকল দুর্নীতিবাজদের পাছ...      anger
# 1390  আমি ভেবেছিলাম এই গান টা ইংলিশ তারপর দেখি বংলা ...   surprise
# 1391  এই শব্দটার মধ্যে আসলে একধরণের ক্ষমতা আছে বলে আ...       fear
# 1392  আমার এই ক্ষুদ্র জীবনে পাওয়া এইরকম মানুষদের মধ...        joy
# 1393  নেক্সট লেভেলের ইডিটিং এন্ড কন্টেন্ট   সুপার  \...        joy
# 1394  করোনা চিকিৎসায় চট্টগ্রামের অবস্থা  ঢাল নেই তল...      anger
# 1395  যেখানে ভিডিওটা বন্ধ হইসে  সিভিলের ওইদিক থেকে ত...       fear
# 1396  গাজীপুরের শ্রীপুর উপজেলার নয়নপুর এলাকায় আজ ম...    sadness
# 1397  নারীরা কোনো উদ্যোগ নিয়ে মাঠে নামতে চাইলে তাঁর...        joy
# 1398  হঠাৎ লোকটা আমাকে কয়েকটি সাংকেতিক শব্দ বললো  আ...       fear
# 1399   আবেশ আতঙ্ক এক ধরণের ভয় যা সময়ের সাথে বেড়ে চলে       fear
#
#      Predicted_Label  Token_Length
# 1375            fear            24
# 1376            fear            16
# 1377            fear            35
# 1378             joy            13
# 1379             joy            16
# 1380             joy            22
# 1381         disgust            27
# 1382         disgust             6
# 1383            fear            17
# 1384             joy            14
# 1385             joy            25
# 1386         disgust            10
# 1387        surprise            29
# 1388         disgust            18
# 1389           anger            14
# 1390             joy            26
# 1391        surprise            23
# 1392             joy            10
# 1393             joy            17
# 1394         sadness            22
# 1395            fear            18
# 1396         sadness            50
# 1397             joy            24
# 1398            fear            27
# 1399            fear            10

# %%
def PlotGraph(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  x = range(1, len(acc) + 1)
  plt.figure(figsize=(12, 5))
  plt.subplot(1, 2, 1)
  plt.plot(x, acc, 'g', label='Training acc')
  plt.plot(x, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()
  plt.subplot(1, 2, 2)
  plt.plot(x, loss, 'g', label='Training loss')
  plt.plot(x, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

# %%
PlotGraph(history)

# %%
predictor=ktrain.get_predictor(learner.model, preproc=t)

# %%
predictor.predict(" I'm sorry about this post. It's gonna be a whole lot of hand wringing and mental masturbation. But I never seem to be able to process this in a meaningful way - and it makes attending NA and AA meetings a real pain. I don't seem to have the same kind of sickness that everyone else is describing - I'm having trouble relating to anyone at all there. I don't know what it's like for normal functional people, nor do I know what it's like for people who taste 1% beer and come to next month in jail after charging a rhino to a military convoy dressed in wehrmact univorm. Instead of this all-encompassing disease people speak of in groups it's like a slight poly-addiction as parts of the maladaptive patterns I've learned due to ADHD - and the cravings themselves are way lessened due to starting on strattera")
# Out:
# 'disgust'

# %%
predictor.explain(" I'm sorry about this post. It's gonna be a whole lot of hand wringing and mental masturbation. But I never seem to be able to process this in a meaningful way - and it makes attending NA and AA meetings a real pain. I don't seem to have the same kind of sickness that everyone else is describing - I'm having trouble relating to anyone at all there. I don't know what it's like for normal functional people, nor do I know what it's like for people who taste 1% beer and come to next month in jail after charging a rhino to a military convoy dressed in wehrmact univorm. Instead of this all-encompassing disease people speak of in groups it's like a slight poly-addiction as parts of the maladaptive patterns I've learned due to ADHD - and the cravings themselves are way lessened due to starting on strattera ")
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=disgust
#
# </b>
#
#
#     (probability <b>0.905</b>, score <b>4.068</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.077
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x164
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.840
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x55
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.782
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x226
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.730
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x198
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.696
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x53
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.619
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x217
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.527
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x142
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.525
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x197
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.449
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x86
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.444
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x61
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.416
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x110
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.395
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x158
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.09%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.395
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x57
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.329
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x228
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.321
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x119
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.319
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x237
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.302
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x126
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.300
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x187
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.294
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x243
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.94%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.243
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x239
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.238
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x146
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.214
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x66
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em

# %%
# Make predictions on the entire dataset
y_pred = predictor.predict(X_test)
