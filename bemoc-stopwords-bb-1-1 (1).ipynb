# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install bnlp_toolkit
# Out:
# Collecting bnlp_toolkit
#   Obtaining dependency information for bnlp_toolkit from https://files.pythonhosted.org/packages/af/99/5d688fc2e5f6494d6c0a4e6bcdc8192266869caeef3b41dbc3dc8358616d/bnlp_toolkit-4.0.0-py3-none-any.whl.metadata
#   Downloading bnlp_toolkit-4.0.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (0.1.99)
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (4.3.2)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (3.2.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (1.11.3)
# Collecting sklearn-crfsuite (from bnlp_toolkit)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (4.66.1)
# Collecting ftfy (from bnlp_toolkit)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Collecting emoji==1.7.0 (from bnlp_toolkit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 5.5 MB/s eta 0:00:00
# done
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from bnlp_toolkit) (2.31.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->bnlp_toolkit)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim->bnlp_toolkit) (6.3.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->bnlp_toolkit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->bnlp_toolkit) (2023.7.22)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite->bnlp_toolkit)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from sklearn-crfsuite->bnlp_toolkit) (0.9.0)
# Downloading bnlp_toolkit-4.0.0-py3-none-any.whl (22 kB)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 5.4 MB/s eta 0:00:00
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: emoji
# done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171033 sha256=c9bfb00eb49ba7ee89ebc5a840edf9003044370d19e5b711b9063cf066b17207
#   Stored in directory: /root/.cache/pip/wheels/31/8a/8c/315c9e5d7773f74b33d5ed33f075b49c6eaeb7cedbb86e2cf8
# Successfully built emoji
# Installing collected packages: wcwidth, python-crfsuite, emoji, sklearn-crfsuite, ftfy, bnlp_toolkit
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.6
#     Uninstalling wcwidth-0.2.6:
#       Successfully uninstalled wcwidth-0.2.6
#   Attempting uninstall: emoji
#     Found existing installation: emoji 2.8.0
#     Uninstalling emoji-2.8.0:
#       Successfully uninstalled emoji-2.8.0
# Successfully installed bnlp_toolkit-4.0.0 emoji-1.7.0 ftfy-6.1.3 python-crfsuite-0.9.9 sklearn-crfsuite-0.3.6 wcwidth-0.2.12
# Note: you may need to restart the kernel to use updated packages.

# %%
train_df = pd.read_excel("/kaggle/input/bemoc-dataset/cleaned_BEmoC7k.xlsx")

# %%
train_df.head()
# Out:
#                                                 TEXT  classes
# 0                           নাইমা কি করবেন আমরা জানি  sadness
# 1                       ভাই সব আপনাদের খুব ভাল লাগছে      joy
# 2  গাঞ্জা খাইয়া নিউজ শেয়ার করছে দিগন্ত  বয়কটে ...    anger
# 3  অনেক ধন্যবাদ স্যার যশোরে ইত্যাদি অনুষ্ঠান করার...      joy
# 4      বর্তমানে মুসলমান মারে যে জন সে জন হয়েছে ঈশ্বর  disgust

# %%
train_df.dropna(inplace=True)

# %%
longest_string = max(train_df["TEXT"], key=len)
print(len(longest_string))
# Out:
# 1093

# %%
from bnlp import CleanText

clean_text = CleanText(
   fix_unicode=True,
   unicode_norm=True,
   unicode_norm_form="NFKC",
   remove_url=False,
   remove_email=False,
   remove_emoji=False,
   remove_number=False,
   remove_digits=False,
   remove_punct=False,
   replace_with_url="<URL>",
   replace_with_email="<EMAIL>",
   replace_with_number="<NUMBER>",
   replace_with_digit="<DIGIT>",
   replace_with_punct = "<PUNC>"
)

train_df['TEXT'] = train_df['TEXT'].apply(clean_text)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
longest_string = max(train_df["TEXT"], key=len)
print(len(longest_string))
# Out:
# 1120

# %%
train_df["classes"].value_counts()
# Out:
# classes
# joy         1524
# disgust     1356
# sadness     1327
# anger       1052
# fear         962
# surprise     779
# Name: count, dtype: int64

# %%
from bnlp import BengaliCorpus as corpus

stop_words = set(corpus.stopwords)

# %%
stopwords_length = len(stop_words)

print("Number of stopwords:", stopwords_length)
# Out:
# Number of stopwords: 398

# %%
# for stopword in stop_words:
#     print(stopword)

# %%
stopwords_to_keep = {'অতএব', 'অথচ', 'অবধি', 'অর্থাত', 'আই', 'আর', 'আরও', 'ই', 'ইহা', 
                     'এ', 'এই', 'একই', 'একে', 'এটা', 'এটাই', 'এত', 'এতে', 'এব', 'এর', 
                     'এস', 'ঐ', 'ও', 'ওঁর', 'ওঁরা', 'ওই', 'ওকে', 'ওর', 'ওরা', 'কমনে', 
                     'করা', 'করাই', 'করায়', 'করিয়ে', 'করেই', 'কাছ', 'কারও', 'কি', 'কিংবা',
                     'কী', 'কে', 'কেউ', 'কেউই', 'কেখা', 'ছাড়াও', 'জন্যওজে', 'জানিয়েছে', 
                     'জে', 'জ্নজন', 'টি', 'তত', 'তা', 'তাঁাহারা', 'তাই', 'তাও', 'তাতে', 
                     'তারৈ', 'তাহা', 'তাহাতে', 'তিনঐ', 'তুলে', 'তো', 'দু', 'ধামার', 'পরেই', 
                     'পাচ', 'পি', 'পেয়্র্', 'প্রযন্ত', 'ফের', 'বরং', 'বহু', 'বা', 'বি', 'মোটেই',
                     'যা', 'যে', 'র', 'সহ', 'সহিত', 'সি', 'সে', 'সেই', 'সেটাই', 'স্বয়ং',
                     'হত', 'হতেই', 'হন', 'হয়েই', 'হয়নি', 'হতেই'}


filtered_stop_words = stop_words.intersection(stopwords_to_keep)

# %%
stopwords_length = len(filtered_stop_words)

print("Number of filtered stopwords :", stopwords_length)
# Out:
# Number of filtered stopwords : 89

# %%
# for stopword in filtered_stop_words:
#     print(stopword)

# %%
from bnlp import NLTKTokenizer

# %%
# Initialize tokenizer
bnltk = NLTKTokenizer()

# Function to remove stopwords
def remove_stopwords(text):
    words = bnltk.word_tokenize(text)
    filtered_words = [word for word in words if word not in filtered_stop_words]
    return ' '.join(filtered_words)

train_df['TEXT'] = train_df['TEXT'].apply(remove_stopwords)

# %%
train_df
# Out:
#                                                    TEXT  classes
# 0                                 নাইমা করবেন আমরা জানি  sadness
# 1                          ভাই সব আপনাদের খুব ভাল লাগছে      joy
# 2     গাঞ্জা খাইয়া নিউজ শেয়ার করছে দিগন্ত বয়কটে ক...    anger
# 3     অনেক ধন্যবাদ স্যার যশোরে ইত্যাদি অনুষ্ঠান করার...      joy
# 4              বর্তমানে মুসলমান মারে জন জন হয়েছে ঈশ্বর  disgust
# ...                                                 ...      ...
# 6995  হে আল্লাহ আপনি আমাদের দেশের প্রতি সহায়ক মহামা...  sadness
# 6996  ঈদ ছারাও যুদি বাংলাদেশ ঈদের খুশির অামেজ পান তব...      joy
# 6997  বছরের সবচেয়ে সেরা ভিডিও দেখেছি আমাদের দেশের স...      joy
# 6998    কিরে মিথ্যা কথা কস কেন গতদিন আমি আসিফ আসছি খালি    anger
# 6999  ভাইরেভাই বেস্ট এইটা বেস্ট এইরকম পারফেক্ট গল্প ...      joy
#
# [7000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(train_df, test_size=0.2,stratify=train_df['classes'],random_state=42)

# %%
X_train  =  train_df['TEXT'].values.tolist()
y_train = train_df['classes'].tolist()

# %%
X_test =  test_df['TEXT'].values.tolist()
y_test = test_df['classes'].tolist()

# %%
pip install ktrain
# Out:
# Collecting ktrain
#   Downloading ktrain-0.39.0.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 51.5 MB/s eta 0:00:00
# done
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.7.3)
# Requirement already satisfied: pandas>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.0.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from ktrain) (21.3)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 45.8 MB/s eta 0:00:00
# done
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.42.1)
# Requirement already satisfied: charset-normalizer in /opt/conda/lib/python3.10/site-packages (from ktrain) (3.2.0)
# Collecting chardet (from ktrain)
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
# done
# Requirement already satisfied: transformers>=4.17.0 in /opt/conda/lib/python3.10/site-packages (from ktrain) (4.35.0)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
# done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 33.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras_bert>=0.86.0->ktrain) (1.24.3)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
# done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
# done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
# done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
# done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
# done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
# done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# done
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.0.1->ktrain) (2023.3)
# Requirement already satisfied: regex>2016 in /opt/conda/lib/python3.10/site-packages (from syntok>1.3.3->ktrain) (2023.8.8)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (6.0.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->ktrain) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tika->ktrain) (68.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (4.5.0)
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 15.8 MB/s eta 0:00:00
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, langdetect, tika
# done
#   Created wheel for ktrain: filename=ktrain-0.39.0-py3-none-any.whl size=25319738 sha256=2fa06f3ff7315ab81122fe9240998d09c264dc98623a0b47f50a1db94755e430
#   Stored in directory: /root/.cache/pip/wheels/98/fd/0a/ef6252223f3d2c49b06d18e71c74caa43bbf4c64a8c183a46e
# done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33499 sha256=e772f838dfc6e3757277cd9e27d674a258af6281b5485c0011d18a32796b9d0f
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
# done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12285 sha256=c20c7c4354005a1207eeeb12d276da56668c3961605f297b0521eaab97adb699
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
# done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3945 sha256=31bb3562fb3d603be864f3ae95fba9331907e10b51784c74147e6f19c9a5d59b
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
# done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4654 sha256=3515c6405ac83c9af42e6db74fbb357939d3d451794c5e222c2b043bd330b684
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
# done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14977 sha256=0679616482b3fcae3532b586380fa31c1f43b334f0cd49a5ad5928732399ee97
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
# done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6945 sha256=b317b2ce750723ec06b807d0298261ab68422427f29d2999898fb59e142cd426
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
# done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4969 sha256=1f041aa719067c627840a4db104ff073b33d42d9d12abaae81315f3591aac2e9
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
# done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18895 sha256=2bd9114f785068ea471dec14c33e98b88d698ac9fa7cdcf5f64408f42aac9388
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
# done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=01e3f35b313121af56097bc139e425da3d7624ccb57dfec57c3e4d97c35d5f36
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=e988b9d22badd327342c3f4ac4be004e2c59f51d23f2f4d56b919fb1cd2aafd4
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention langdetect tika
# Installing collected packages: whoosh, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, chardet, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed chardet-5.2.0 keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.39.0 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import ktrain
from ktrain import text
MODEL_NAME = 'csebuetnlp/banglabert'
t = text.Transformer(MODEL_NAME, maxlen=500)
# Out:
# Downloading config.json:   0%|          | 0.00/586 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
trn = t.preprocess_train(X_train, y_train)
val = t.preprocess_test(X_test, y_test)
# Out:
# preprocessing train...
# language: bn
# train sequence lengths:
# 	mean : 20
# 	95percentile : 38
# 	99percentile : 52
# Downloading tokenizer_config.json:   0%|          | 0.00/119 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/528k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: bn
# test sequence lengths:
# 	mean : 20
# 	95percentile : 38
# 	99percentile : 56
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
print(trn)
# Out:
# <ktrain.text.dataset.TransformerDataset object at 0x7a53732238e0>

# %%
import matplotlib.pyplot as plt

# Calculate token lengths for train and test datasets
train_token_lengths = [len(t.split()) for t in X_train]
test_token_lengths = [len(t.split()) for t in X_test]

# Plot token length distribution
plt.figure(figsize=(10, 6))
plt.hist(train_token_lengths, bins=50, alpha=0.5, color='blue', label='Train')
plt.hist(test_token_lengths, bins=50, alpha=0.5, color='orange', label='Test')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.title('Token Length Distribution')
plt.legend()
plt.show()

# %%
model = t.get_classifier()

# %%
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=8)

# %%
# Adding early stopping callback from TensorFlow
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='auto')

# %%
history = learner.autofit(2e-5, 10, callbacks=[early_stopping])
# Out:
# begin training using triangular learning rate policy with max lr of 2e-05...
# Epoch 1/10
# 700/700 [==============================] - 430s 577ms/step - loss: 1.3217 - accuracy: 0.4882 - val_loss: 0.8626 - val_accuracy: 0.6957
# Epoch 2/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.7911 - accuracy: 0.7089 - val_loss: 0.7855 - val_accuracy: 0.6993
# Epoch 3/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.5985 - accuracy: 0.7855 - val_loss: 0.8354 - val_accuracy: 0.7043
# Epoch 4/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.4616 - accuracy: 0.8432 - val_loss: 0.8546 - val_accuracy: 0.7079
# Epoch 5/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.3463 - accuracy: 0.8861 - val_loss: 0.9267 - val_accuracy: 0.7121
# Epoch 6/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.2719 - accuracy: 0.9155 - val_loss: 1.0256 - val_accuracy: 0.6993
# Epoch 7/10
# 700/700 [==============================] - 399s 570ms/step - loss: 0.2129 - accuracy: 0.9375 - val_loss: 1.0911 - val_accuracy: 0.7093

# %%
# Save the trained model
learner.save_model('/kaggle/output/bemoc.zip')

# %%
classes=t.get_classes()

# %%
cm = learner.validate(class_names=t.get_classes())
# Out:
# 44/44 [==============================] - 11s 177ms/step
#               precision    recall  f1-score   support
#
#        anger       0.61      0.57      0.59       211
#      disgust       0.57      0.59      0.58       271
#         fear       0.84      0.80      0.82       192
#          joy       0.84      0.85      0.84       305
#      sadness       0.70      0.74      0.72       265
#     surprise       0.68      0.67      0.67       156
#
#     accuracy                           0.71      1400
#    macro avg       0.71      0.70      0.70      1400
# weighted avg       0.71      0.71      0.71      1400

# %%
import os
import subprocess
from IPython.display import FileLink, display

def download_file(path, download_file_name):
    os.chdir('/kaggle/working/')
    zip_name = f"/kaggle/working/{download_file_name}.zip"
    command = f"zip {zip_name} {path} -r"
    result = subprocess.run(command, shell=True, capture_output=True, text=True)
    if result.returncode != 0:
        print("Unable to run zip command!")
        print(result.stderr)
        return
    display(FileLink(f'{download_file_name}.zip'))

# %%
# !zip -r mental.zip /kaggle/output/mental-health-rand
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 	zip warning: name not matched: /kaggle/output/mental-health-rand
#
# zip error: Nothing to do! (try: zip -r mental.zip . -i /kaggle/output/mental-health-rand)

# %%
# !ls
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# __notebook__.ipynb

# %%
from IPython.display import FileLink
FileLink(r'/kaggle/working/mental-health-rand.zip')
# Out:
# /kaggle/working/mental-health-rand.zip

# %%
# Get predictions for the test data
preds = learner.predict(val)

# Convert the predicted probabilities to class labels
predicted_labels = np.argmax(preds, axis=1)

# Get the list of class labels
class_labels = t.get_classes()

# Map predicted labels to class labels
predicted_labels = [class_labels[label] for label in predicted_labels]

# Create a DataFrame to store the results
results_df = pd.DataFrame({'Text': X_test, 'True_Label': y_test, 'Predicted_Label': predicted_labels})

# Display the results DataFrame
print(results_df)

# Save the results to a CSV file
results_df.to_csv('classification_results.csv', index=False)
# Out:
# 44/44 [==============================] - 7s 163ms/step
#                                                    Text True_Label  \
# 0     বাইরে কেমন যেন একটা খসখস শব্দ হচ্ছে তার মনে হচ...       fear
# 1     সোনা বিদেশি মুদ্রা উদ্ধারের মামলায় পুরান ঢাকা...    disgust
# 2     সরকারি নিষেধাজ্ঞায় গত মে থেকে টানা দিনের জন্য...    sadness
# 3     আমি তাকে সঙ্গে সঙ্গে চিনে ফেললাম আশ্চর্য কিরন ...   surprise
# 4     এবারের মিস ওয়ার্ল্ড বাংলাদেশ ভিডিওতে দেখেছি ক...    disgust
# ...                                                 ...        ...
# 1395  যেখানে ভিডিওটা বন্ধ হইসে সিভিলের ওইদিক থেকে তি...       fear
# 1396  গাজীপুরের শ্রীপুর উপজেলার নয়নপুর এলাকায় আজ ম...    sadness
# 1397  নারীরা কোনো উদ্যোগ নিয়ে মাঠে নামতে চাইলে তাঁর...        joy
# 1398  হঠাৎ লোকটা আমাকে কয়েকটি সাংকেতিক শব্দ বললো আম...       fear
# 1399      আবেশ আতঙ্ক এক ধরণের ভয় সময়ের সাথে বেড়ে চলে       fear
#
#      Predicted_Label
# 0               fear
# 1            disgust
# 2            sadness
# 3           surprise
# 4            disgust
# ...              ...
# 1395            fear
# 1396         sadness
# 1397             joy
# 1398            fear
# 1399            fear
#
# [1400 rows x 3 columns]

# %%
results_df["Predicted_Label"].value_counts()
# Out:
# Predicted_Label
# joy         306
# sadness     282
# disgust     279
# anger       197
# fear        183
# surprise    153
# Name: count, dtype: int64

# %%
results_df["True_Label"].value_counts()
# Out:
# True_Label
# joy         305
# disgust     271
# sadness     265
# anger       211
# fear        192
# surprise    156
# Name: count, dtype: int64

# %%
# Calculate token lengths for each description
results_df['Token_Length'] = results_df['Text'].apply(lambda x: len(x.split()))

# Separate data for correct and wrong predictions
correct_preds = results_df[results_df['True_Label'] == results_df['Predicted_Label']]
wrong_preds = results_df[results_df['True_Label'] != results_df['Predicted_Label']]

# Create histograms for token lengths
plt.figure(figsize=(12, 6))
plt.hist(correct_preds['Token_Length'], bins=20, alpha=0.5, label='Correct Predictions')
plt.hist(wrong_preds['Token_Length'], bins=20, alpha=0.5, label='Wrong Predictions')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.title('Token Length Distribution')
plt.legend()
plt.show()

# %%
results_df.tail(25)
# Out:
#                                                    Text True_Label  \
# 1375  করোনা ভাইরাসের জন্য স্কুল বন্ধ করে দেওয়া হয়ে...    disgust
# 1376  আমার কাছে মনে হচ্ছে পুরো পৃথিবী যেন থমকে আছে এ...       fear
# 1377  তার গা শিহরে উঠে ভয়ে কানের সামনে পিছনের চুল গ...       fear
# 1378  মানুষটা পারে কাঁটাতারের দুপাশে থাকা মানুষগুলোর...        joy
# 1379  সত্যিই পরিচালকটা অনেক ব্রিলিয়েন্ট জিৎ দার চেহ...        joy
# 1380  পুরাই এপিক হাসতে হাসতে মরে গেলাম আমার মনে হচ্ছ...        joy
# 1381  কক্সবাজারের কুতুবদিয়া উপজেলায় দুই স্কুলছাত্র...      anger
# 1382                              এগুলো সব ধোন নুনু জাত    disgust
# 1383  পুকুর পাড়ে যেন মড়ার মত শুয়ে আছে কাছে গিয়ে ...       fear
# 1384  সব ঠিক আছে তুই মেয়ে ভাল স্ট্রং ক্যারেক্টার শক...        joy
# 1385  খুব ছোটবেলায় মাতৃহীন হলেও বিত্তশালী পিতার কড়...    sadness
# 1386  তাহসানের মত মানুষকে মিথিলা ছেড়ে চলে গেছে কোপা...    disgust
# 1387  প্রায় অনেকটা হাঁটার পর একটা রিকশার দেখা মিললো...   surprise
# 1388  মানুষজন নাকি বছরে বারবার আলহামদুলিল্লাহ ওয়ালা...    disgust
# 1389  বাফুফেরর সাথে সংশ্লিষ্ট সকল দুর্নীতিবাজদের পাছ...      anger
# 1390  আমি ভেবেছিলাম গান টা ইংলিশ তারপর দেখি বংলা আমা...   surprise
# 1391  শব্দটার মধ্যে আসলে একধরণের ক্ষমতা আছে বলে আমার...       fear
# 1392  আমার ক্ষুদ্র জীবনে পাওয়া এইরকম মানুষদের মধ্যে...        joy
# 1393  নেক্সট লেভেলের ইডিটিং এন্ড কন্টেন্ট সুপার আমাদ...        joy
# 1394  করোনা চিকিৎসায় চট্টগ্রামের অবস্থা ঢাল নেই তলো...      anger
# 1395  যেখানে ভিডিওটা বন্ধ হইসে সিভিলের ওইদিক থেকে তি...       fear
# 1396  গাজীপুরের শ্রীপুর উপজেলার নয়নপুর এলাকায় আজ ম...    sadness
# 1397  নারীরা কোনো উদ্যোগ নিয়ে মাঠে নামতে চাইলে তাঁর...        joy
# 1398  হঠাৎ লোকটা আমাকে কয়েকটি সাংকেতিক শব্দ বললো আম...       fear
# 1399      আবেশ আতঙ্ক এক ধরণের ভয় সময়ের সাথে বেড়ে চলে       fear
#
#      Predicted_Label  Token_Length
# 1375            fear            23
# 1376            fear            16
# 1377            fear            32
# 1378         sadness            12
# 1379             joy            14
# 1380             joy            20
# 1381         disgust            25
# 1382         disgust             5
# 1383            fear            15
# 1384             joy            13
# 1385             joy            23
# 1386         sadness            10
# 1387        surprise            27
# 1388         disgust            16
# 1389           anger            13
# 1390        surprise            21
# 1391            fear            21
# 1392             joy             9
# 1393             joy            17
# 1394         sadness            22
# 1395            fear            18
# 1396         sadness            49
# 1397             joy            21
# 1398            fear            27
# 1399            fear             9

# %%
def PlotGraph(history):
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  x = range(1, len(acc) + 1)
  plt.figure(figsize=(12, 5))
  plt.subplot(1, 2, 1)
  plt.plot(x, acc, 'g', label='Training acc')
  plt.plot(x, val_acc, 'b', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()
  plt.subplot(1, 2, 2)
  plt.plot(x, loss, 'g', label='Training loss')
  plt.plot(x, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

# %%
PlotGraph(history)

# %%
predictor=ktrain.get_predictor(learner.model, preproc=t)

# %%
predictor.predict(" I'm sorry about this post. It's gonna be a whole lot of hand wringing and mental masturbation. But I never seem to be able to process this in a meaningful way - and it makes attending NA and AA meetings a real pain. I don't seem to have the same kind of sickness that everyone else is describing - I'm having trouble relating to anyone at all there. I don't know what it's like for normal functional people, nor do I know what it's like for people who taste 1% beer and come to next month in jail after charging a rhino to a military convoy dressed in wehrmact univorm. Instead of this all-encompassing disease people speak of in groups it's like a slight poly-addiction as parts of the maladaptive patterns I've learned due to ADHD - and the cravings themselves are way lessened due to starting on strattera")
# Out:
# 'disgust'

# %%
predictor.explain(" I'm sorry about this post. It's gonna be a whole lot of hand wringing and mental masturbation. But I never seem to be able to process this in a meaningful way - and it makes attending NA and AA meetings a real pain. I don't seem to have the same kind of sickness that everyone else is describing - I'm having trouble relating to anyone at all there. I don't know what it's like for normal functional people, nor do I know what it's like for people who taste 1% beer and come to next month in jail after charging a rhino to a military convoy dressed in wehrmact univorm. Instead of this all-encompassing disease people speak of in groups it's like a slight poly-addiction as parts of the maladaptive patterns I've learned due to ADHD - and the cravings themselves are way lessened due to starting on strattera ")
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=disgust
#
# </b>
#
#
#     (probability <b>0.690</b>, score <b>0.369</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.480
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x164
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.461
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x55
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.407
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x132
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.377
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x237
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.375
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x63
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.23%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.373
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x105
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.345
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x116
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.335
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x209
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.318
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x53
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x89
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.305
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x130
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.292
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x128
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.283
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x126
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.263
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x217
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.259
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x203
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.255
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x21
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.253
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x6
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.246
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x99
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.239
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x193
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.235
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x123
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.231
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x176
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.223
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         x114
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em;

# %%
# Make predictions on the entire dataset
y_pred = predictor.predict(X_test)

# %%
# # Get the explanation of the model's predictions on the entire dataset
# explanations = []
# for text_instance in X_test:
#     explanation = predictor.explain(text_instance)
#     explanations.append(explanation)

# # Print the top contributing and distracting terms for each prediction
# for i in range(len(X_test)):
#     print('Description:', X_test[i])
#     print('Actual label:', y_test[i])
#     print('Predicted label:', y_pred[i])
#     print('Contributing terms:', explanations[i]['pos'])
#     print('Distracting terms:', explanations[i]['neg'])
#     print('-------------------------------------------------')

# %%
# import seaborn as sns

# %%
# df_cm = pd.DataFrame(cm, index=["Anxiety","Bipolar","Borderline Personality", "Depression ", "Schizophernia","Suidal Thought","neutral",
#                                 "Alcoholism","Addiction","Aspergers","SelfHarm "],
#                      columns=["Anxiety","Bipolar","Borderline Personality", "Depression ", "Schizophernia","Suidal Thought","neutral",
#                                 "Alcoholism","Addiction","Aspergers","SelfHarm "])
# plt.figure(figsize = (10,7))
# sns.heatmap(df_cm,annot=True, fmt ="d")
